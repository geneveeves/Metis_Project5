# %%
# Imports
import numpy as np
import pandas as pd

# %%
# Read in US Foreign Aid dataset
hdi = pd.read_csv('Data/HumanDevelopmentIndex.csv', header=[1])

# %%
hdi.head()
# Out:
#    HDI Rank (2017)       Country   1990  Unnamed: 3   1991  Unnamed: 5   1992  \
# 0            168.0   Afghanistan    NaN         NaN    NaN         NaN    NaN
# 1             68.0       Albania  0.645         NaN  0.626         NaN  0.610
# 2             85.0       Algeria  0.577         NaN  0.581         NaN  0.587
# 3             35.0       Andorra    NaN         NaN    NaN         NaN    NaN
# 4            147.0        Angola    NaN         NaN    NaN         NaN    NaN
#
#    Unnamed: 7   1993  Unnamed: 9  ...   2013  Unnamed: 49   2014  Unnamed: 51  \
# 0         NaN    NaN         NaN  ...  0.487          NaN  0.491          NaN
# 1         NaN  0.613         NaN  ...  0.771          NaN  0.773          NaN
# 2         NaN  0.591         NaN  ...  0.745          NaN  0.747          NaN
# 3         NaN    NaN         NaN  ...  0.850          NaN  0.853          NaN
# 4         NaN    NaN         NaN  ...  0.554          NaN  0.564          NaN
#
# ...

# %%
# Need to remove all columns with 'Unnamed: _' in the title
hdi = hdi.loc[:, ~hdi.columns.str.contains('^Unnamed')]

# %%
hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 30 columns):
# HDI Rank (2017)    189 non-null float64
# Country            189 non-null object
# 1990               142 non-null float64
# 1991               143 non-null float64
# 1992               140 non-null float64
# 1993               143 non-null float64
# 1994               143 non-null float64
# 1995               147 non-null float64
# 1996               147 non-null float64
# 1997               147 non-null float64
# 1998               147 non-null float64
# 1999               150 non-null float64
# 2000               172 non-null float64
# 2001               172 non-null float64
# 2002               174 non-null float64
# 2003               176 non-null float64
# 2004               179 non-null float64
# 2005               186 non-null float64
# 2006               186 non-null float64
# 2007               186 non-null float64
# 2008               186 non-null float64
# ...

# %%
# Next, convert from HDI values, to change in HDI from previous year
