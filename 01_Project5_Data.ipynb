# %%
# Imports
import numpy as np
import pandas as pd

# %%
# Read in US Foreign Aid dataset
df = pd.read_csv('us_foreign_aid_complete.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986235 entries, 0 to 986234
# Data columns (total 48 columns):
# country_id                     986235 non-null int64
# country_code                   985949 non-null object
# country_name                   986235 non-null object
# region_id                      986235 non-null int64
# region_name                    986235 non-null object
# income_group_id                791788 non-null float64
# income_group_name              791788 non-null object
# income_group_acronym           791788 non-null object
# implementing_agency_id         986235 non-null int64
# implementing_agency_acronym    985536 non-null object
# implementing_agency_name       986235 non-null object
# implementing_subagency_id      986235 non-null int64
# subagency_acronym              888366 non-null object
# subagency_name                 986235 non-null object
# channel_category_id            986235 non-null int64
# ...

# %%
df.head()
# Out:
#    country_id country_code country_name  region_id             region_name  \
# 0           4          AFG  Afghanistan          4  South and Central Asia
# 1           4          AFG  Afghanistan          4  South and Central Asia
# 2           4          AFG  Afghanistan          4  South and Central Asia
# 3           4          AFG  Afghanistan          4  South and Central Asia
# 4           4          AFG  Afghanistan          4  South and Central Asia
#
#    income_group_id   income_group_name income_group_acronym  \
# 0              1.0  Low Income Country                  LIC
# 1              1.0  Low Income Country                  LIC
# 2              1.0  Low Income Country                  LIC
# 3              1.0  Low Income Country                  LIC
# 4              1.0  Low Income Country                  LIC
#
#    implementing_agency_id implementing_agency_acronym  ...  \
# 0                       7                         DOD  ...
# ...

# %%
df.fiscal_year.unique()
# Out:
# array(['2011', '2012', '2013', '2015', '2010', '2008', '2009', '2006',
#        '2014', '2017', '2007', '2003', '2016', '1947', '1973', '2000',
#        '1979', '1972', '1995', '2005', '2004', '1996', '2002', '1993',
#        '2001', '1985', '1994', '1986', '1999', '1991', '1971', '1988',
#        '1998', '1992', '1997', '1987', '1989', '1990', '1974', '1970',
#        '1952', '2018', '1949', '1984', '1969', '1951', '1982', '1983',
#        '1980', '1981', '1978', '1968', '1950', '1976', '2019', '1977',
#        '1954', '1946', '1967', '1966', '1975', '1976tq', '1962', '1956',
#        '1953', '1948', '1963', '1959', '1957', '1965', '1955', '1964',
#        '1960', '1961', '1958', 2012, 2011, 2002, 2009, 2007, 2001, 2010,
#        2008, 2018, 2003, 2004, 2014, 2006, 2016, 2017, 2005, 2015, 2013,
#        2019, 2000, 1999, 1990, 1998, 1997, 1996, 1959, 1992, 1993, 1969,
#        1995, 1966, 1967, 1991, 1989, 1994, 1973, 1974, 1988, 1955, 1977,
# ...
