# %%
# Data
import numpy as np
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
# %config InlineBackend.figure_formats = ['retina']
sns.set_style("white")

# %%
# Read in clean USAID data pickle
usaid = pd.read_pickle('./clean_usaid.pkl')

# %%
usaid.head()
# Out:
#   country_name             region_name   income_group_name  \
# 0  Afghanistan  South and Central Asia  Low Income Country
# 1  Afghanistan  South and Central Asia  Low Income Country
# 4  Afghanistan  South and Central Asia  Low Income Country
# 7  Afghanistan  South and Central Asia  Low Income Country
# 9  Afghanistan  South and Central Asia  Low Income Country
#
#   implementing_agency_name dac_category_name                dac_sector_name  \
# 0    Department of Defense        Governance  Conflict, Peace, and Security
# 1    Department of Defense        Governance  Conflict, Peace, and Security
# 4    Department of Defense        Governance  Conflict, Peace, and Security
# 7    Department of Defense        Governance  Conflict, Peace, and Security
# 9    Department of Defense        Governance  Conflict, Peace, and Security
#
#   assistance_category_name  fiscal_year  constant_amount
# 0                 Military         2011      10914528417
# 1                 Military         2012       9966142830
# 4                 Military         2013       7345968099
# 7                 Military         2010       7245724425
# 9                 Military         2015       6207678503

# %%
usaid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359342 entries, 0 to 986232
# Data columns (total 9 columns):
# country_name                359342 non-null object
# region_name                 359342 non-null object
# income_group_name           359342 non-null object
# implementing_agency_name    359342 non-null object
# dac_category_name           359342 non-null object
# dac_sector_name             359342 non-null object
# assistance_category_name    359342 non-null object
# fiscal_year                 359342 non-null int64
# constant_amount             359342 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 27.4+ MB

# %%
# Read in HDI data pickle
hdi = pd.read_pickle('./hdi_data.pkl')

# %%
hdi.head()
# Out:
#        Country  Year  HDI_Change
# 0  Afghanistan  1990         NaN
# 1      Albania  1990      -0.019
# 2      Algeria  1990       0.004
# 3      Andorra  1990         NaN
# 4       Angola  1990         NaN

# %%
hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5292 entries, 0 to 5318
# Data columns (total 3 columns):
# Country       5292 non-null object
# Year          5292 non-null int64
# HDI_Change    4565 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 165.4+ KB

# %%
# Merge dataframes
df = pd.merge(usaid, hdi,  
              how='left', 
              left_on=['country_name','fiscal_year'], 
              right_on = ['Country','Year'])

# %%
df.head()
# Out:
#   country_name             region_name   income_group_name  \
# 0  Afghanistan  South and Central Asia  Low Income Country
# 1  Afghanistan  South and Central Asia  Low Income Country
# 2  Afghanistan  South and Central Asia  Low Income Country
# 3  Afghanistan  South and Central Asia  Low Income Country
# 4  Afghanistan  South and Central Asia  Low Income Country
#
#   implementing_agency_name dac_category_name                dac_sector_name  \
# 0    Department of Defense        Governance  Conflict, Peace, and Security
# 1    Department of Defense        Governance  Conflict, Peace, and Security
# 2    Department of Defense        Governance  Conflict, Peace, and Security
# 3    Department of Defense        Governance  Conflict, Peace, and Security
# 4    Department of Defense        Governance  Conflict, Peace, and Security
#
#   assistance_category_name  fiscal_year  constant_amount      Country    Year  \
# 0                 Military         2011      10914528417  Afghanistan  2011.0
# 1                 Military         2012       9966142830  Afghanistan  2012.0
# 2                 Military         2013       7345968099  Afghanistan  2013.0
# 3                 Military         2010       7245724425  Afghanistan  2010.0
# 4                 Military         2015       6207678503  Afghanistan  2015.0
#
#    HDI_Change
# 0       0.011
# 1       0.005
# 2       0.004
# 3       0.008
# 4       0.001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359342 entries, 0 to 359341
# Data columns (total 12 columns):
# country_name                359342 non-null object
# region_name                 359342 non-null object
# income_group_name           359342 non-null object
# implementing_agency_name    359342 non-null object
# dac_category_name           359342 non-null object
# dac_sector_name             359342 non-null object
# assistance_category_name    359342 non-null object
# fiscal_year                 359342 non-null int64
# constant_amount             359342 non-null int64
# Country                     355238 non-null object
# Year                        355238 non-null float64
# HDI_Change                  326397 non-null float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 35.6+ MB

# %%
# Drop redundant columns
df.drop(columns = {'Country', 'Year'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359342 entries, 0 to 359341
# Data columns (total 10 columns):
# country_name                359342 non-null object
# region_name                 359342 non-null object
# income_group_name           359342 non-null object
# implementing_agency_name    359342 non-null object
# dac_category_name           359342 non-null object
# dac_sector_name             359342 non-null object
# assistance_category_name    359342 non-null object
# fiscal_year                 359342 non-null int64
# constant_amount             359342 non-null int64
# HDI_Change                  326397 non-null float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 30.2+ MB

# %%
# Countries in the UN HDI dataset that the US has not given aid to
set(hdi.Country) - (set(usaid.country_name) & set(hdi.Country))
# Out:
# {'Andorra', 'Liechtenstein', 'United States'}

# %%
# Countries the US has given to that are not included in the UN HDI dataset
set(usaid.country_name) - (set(usaid.country_name) & set(hdi.Country))
# Out:
# {'Aruba',
#  'Bermuda',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'China, Republic of (Taiwan)',
#  'Curacao',
#  'Korea, Democratic Republic',
#  'Kosovo',
#  'Macau',
#  'Nauru',
#  'New Caledonia',
#  'Somalia',
#  'Turks and Caicos Islands',
#  'Tuvalu'}

# %%
# Drop Null Values for 'HDI_Change'
df = df[pd.notnull(df['HDI_Change'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326397 entries, 0 to 359341
# Data columns (total 10 columns):
# country_name                326397 non-null object
# region_name                 326397 non-null object
# income_group_name           326397 non-null object
# implementing_agency_name    326397 non-null object
# dac_category_name           326397 non-null object
# dac_sector_name             326397 non-null object
# assistance_category_name    326397 non-null object
# fiscal_year                 326397 non-null int64
# constant_amount             326397 non-null int64
# HDI_Change                  326397 non-null float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 27.4+ MB

# %%
### Need to aggregate all individual expenses, sum total aid
### Break down by country/region/income/year/HDI(same for all 
### categories for country in given year), then break down by 
### Miltary/Economic aid, implementing agency, and Sector

df = df.groupby(['country_name', 
                 'region_name', 
                 'income_group_name', 
                 'fiscal_year', 
                 'HDI_Change',  
                 'assistance_category_name', 
                 'implementing_agency_name', 
                 'dac_category_name', 
                 'dac_sector_name']
               ).agg({'constant_amount': 'sum'})

df = df.reset_index()
df.head()
# Out:
#   country_name             region_name   income_group_name  fiscal_year  \
# 0  Afghanistan  South and Central Asia  Low Income Country         2002
# 1  Afghanistan  South and Central Asia  Low Income Country         2002
# 2  Afghanistan  South and Central Asia  Low Income Country         2002
# 3  Afghanistan  South and Central Asia  Low Income Country         2002
# 4  Afghanistan  South and Central Asia  Low Income Country         2002
#
#    HDI_Change assistance_category_name  \
# 0        0.01                 Economic
# 1        0.01                 Economic
# 2        0.01                 Economic
# 3        0.01                 Economic
# 4        0.01                 Economic
#
#                   implementing_agency_name      dac_category_name  \
# 0                Department of Agriculture           Humanitarian
# 1                    Department of Defense             Governance
# 2  Department of Health and Human Services             Governance
# 3  Department of Health and Human Services  Health and Population
# 4                      Department of State             Governance
#
#                  dac_sector_name  constant_amount
# 0             Emergency Response          2037638
# 1  Conflict, Peace, and Security          3284849
# 2  Conflict, Peace, and Security           799882
# 3                   Basic Health          2743823
# 4  Conflict, Peace, and Security          9331957

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51835 entries, 0 to 51834
# Data columns (total 10 columns):
# country_name                51835 non-null object
# region_name                 51835 non-null object
# income_group_name           51835 non-null object
# fiscal_year                 51835 non-null int64
# HDI_Change                  51835 non-null float64
# assistance_category_name    51835 non-null object
# implementing_agency_name    51835 non-null object
# dac_category_name           51835 non-null object
# dac_sector_name             51835 non-null object
# constant_amount             51835 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.0+ MB

# %%
# Pickle combined df
df.to_pickle('./all_data.pkl')

# %%
# Write CSV of combined df
df.to_csv('./all_data.csv')

# %% [markdown]
# # Some initial EDA

# %%
# Which Programs have the most effect on increasing HDI?
df.groupby('dac_sector_name')['HDI_Change'].apply(lambda x: x.mean()).sort_values(ascending=False)
# Out:
# dac_sector_name
# Action Relating To Debt                            0.011333
# Construction                                       0.006882
# Mineral Resources and Mining                       0.006496
# HIV/AIDS                                           0.006365
# Tourism                                            0.006262
# Communications                                     0.006195
# Developmental Food Aid/Food Security Assistance    0.006128
# Basic Health                                       0.006110
# Water Supply and Sanitation                        0.005970
# Maternal and Child Health, Family Planning         0.005879
# Emergency Response                                 0.005876
# Industry                                           0.005863
# Business and Other Services                        0.005783
# Transport and Storage                              0.005776
# Agriculture                                        0.005726
# Operating Expenses                                 0.005706
# Banking and Financial Services                     0.005678
# General Environmental Protection                   0.005675
# Basic Education                                    0.005626
# Secondary Education                                0.005604
# Education, Level Unspecified                       0.005492
# Government and Civil Society                       0.005474
# Other Social Infrastructure and Services           0.005413
# Trade Policy and Regulations                       0.005361
# Conflict, Peace, and Security                      0.005343
# Health, General                                    0.005313
# Energy                                             0.005308
# Other Multisector                                  0.005179
# Disaster Prevention and Preparedness               0.005069
# Post-Secondary Education                           0.004839
# Program Design and Learning                        0.004823
# Reconstruction Relief and Rehabilitation           0.004751
# Administration and Oversight                       0.004510
# Other Commodity Assistance                         0.004412
# Unallocated/ Unspecified                           0.003571
# General Budget Support                             0.003519
# Name: HDI_Change, dtype: float64

# %%
# Debt relief provides the greatest average increase in HDI, BUT 
# it's a super small sample: 2 years in Pakistan, 1 in Kazakhstan
df.loc[df['dac_sector_name'] == 'Action Relating To Debt']
# Out:
#       country_name             region_name            income_group_name  \
# 24671   Kazakhstan  South and Central Asia  Upper Middle Income Country
# 36219     Pakistan  South and Central Asia  Lower Middle Income Country
# 36244     Pakistan  South and Central Asia  Lower Middle Income Country
#
#        fiscal_year  HDI_Change assistance_category_name  \
# 24671         2010       0.007                 Economic
# 36219         2003       0.014                 Economic
# 36244         2004       0.013                 Economic
#
#          implementing_agency_name dac_category_name          dac_sector_name  \
# 24671   Department of Agriculture             Other  Action Relating To Debt
# 36219  Department of the Treasury             Other  Action Relating To Debt
# 36244  Department of the Treasury             Other  Action Relating To Debt
#
#        constant_amount
# 24671        173505861
# 36219        245081311
# 36244        255303287

# %%
#df.loc[df['dac_sector_name'] == 'Construction']

# %%
# Which programs does the US spend the most money on?
df.groupby('dac_sector_name')['constant_amount'].apply(lambda x: x.sum()).sort_values(ascending=False)
# Out:
# dac_sector_name
# Conflict, Peace, and Security                      287054675684
# Other Multisector                                   90825862449
# Government and Civil Society                        58525358653
# Emergency Response                                  52163875892
# HIV/AIDS                                            37012656227
# Energy                                              27063286686
# Other Social Infrastructure and Services            23383300551
# Developmental Food Aid/Food Security Assistance     22439717487
# Agriculture                                         13991722160
# Transport and Storage                               13056270778
# Basic Health                                        12687489725
# Basic Education                                      9476065525
# Operating Expenses                                   9455280688
# Maternal and Child Health, Family Planning           9208344327
# Water Supply and Sanitation                          7416349429
# General Environmental Protection                     6638126062
# Business and Other Services                          6396032535
# General Budget Support                               6371063295
# Banking and Financial Services                       5539269359
# Trade Policy and Regulations                         3284888268
# Reconstruction Relief and Rehabilitation             2852615709
# Mineral Resources and Mining                         2654984569
# Industry                                             2305909755
# Education, Level Unspecified                         2133431279
# Administration and Oversight                         2075328893
# Health, General                                      1810992776
# Other Commodity Assistance                           1547419540
# Post-Secondary Education                             1309779870
# Action Relating To Debt                               673890459
# Program Design and Learning                           644988142
# Disaster Prevention and Preparedness                  597056878
# Communications                                        552970766
# Construction                                          465217895
# Secondary Education                                   288499352
# Tourism                                                84352818
# Unallocated/ Unspecified                               43725676
# Name: constant_amount, dtype: int64

# %%
# Which DAC Categories have the greatest impact?
category_avg_hdi = df.groupby(
    'dac_category_name')['HDI_Change'].apply(
    lambda x: x.mean()).sort_values(ascending=False).reset_index()
category_avg_hdi
# Out:
#        dac_category_name  HDI_Change
# 0   Commodity Assistance    0.006110
# 1  Health and Population    0.006080
# 2            Agriculture    0.005726
# 3        Economic Growth    0.005706
# 4           Humanitarian    0.005683
# 5         Infrastructure    0.005547
# 6              Education    0.005448
# 7             Governance    0.005408
# 8                  Other    0.005350
# 9   Administrative Costs    0.005228

# %%
#df.groupby('implementing_agency_name')['HDI_Change'].apply(lambda x: x.mean()).sort_values(ascending=False)

# %%
# Which DAC Categories does the US spend the most money on?
category_sum_cost = df.groupby(
    'dac_category_name')['constant_amount'].apply(
    lambda x: x.sum()).sort_values(ascending=False).reset_index()
category_sum_cost
# Out:
#        dac_category_name  constant_amount
# 0             Governance     368963334888
# 1                  Other     104552667941
# 2  Health and Population      68135832484
# 3           Humanitarian      55613548479
# 4         Infrastructure      40672528230
# 5   Commodity Assistance      23987137027
# 6        Economic Growth      20730655199
# 7            Agriculture      13991722160
# 8              Education      13207776026
# 9   Administrative Costs      12175597723

# %%
# Merge tables
merged = category_avg_hdi.merge(category_sum_cost, on='dac_category_name')

# %%
# GRAPH THESE!! 
# Set up the matplotlib figure
sns.set_context('poster')

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10), sharex=False, sharey=True)
f.suptitle('Effects & Expense of Program Categories', fontsize=50, y=1.05)

sns.barplot(x='HDI_Change', y='dac_category_name', data=merged, palette="Blues_r", ax=ax1)
ax1.set_xlabel('Average Change in HDI', fontsize=30, labelpad=5)
ax1.set_ylabel(None)

sns.barplot(x='constant_amount', y='dac_category_name', data=merged, palette="Reds_r", ax=ax2)
ax2.set_xlabel('Sum Total Obligations', fontsize=30, labelpad=5)
ax2.set_ylabel(None)


plt.tight_layout(h_pad=2)
sns.despine(left=True)
#sns.set_context("poster")
#sns.barplot(x='HDI_Change', y='dac_category_name', data=category_avg_hdi, palette="hls")
plt.savefig('programs.png', bbox_inches = 'tight');

# %%
# Take a look at which countries the US has given the most aid to from 1990-2017
# Dollar amounts are in 2016 USD
top_10 = df.groupby('country_name').sum().sort_values(
    'constant_amount', ascending = False)['constant_amount'].head(10)
top_10 = top_10.reset_index()
top_10
# Out:
#   country_name  constant_amount
# 0  Afghanistan     108661053672
# 1       Israel     107661487086
# 2         Iraq      77360732819
# 3        Egypt      67516411972
# 4       Russia      23946978382
# 5     Pakistan      19766495963
# 6       Jordan      18388737869
# 7     Colombia      15271134767
# 8     Ethiopia      11918207045
# 9        Kenya      10854815893

# %%
plt.figure(figsize=(16, 16))
sns.set_context("poster")
sns.barplot(x='constant_amount', y='country_name', data=top_10, palette="hls")
#plt.savefig('top_20_countries.png', bbox_inches = 'tight');

# %%
# Top 10 for most change?

# %%
# Top 10 by year
# Merge dataframes
top_10_by_year = pd.merge(df, top_10, how='inner', on='country_name'
                         ).groupby(['country_name', 'fiscal_year']
                                  )['constant_amount_x'].sum().reset_index()
top_10_by_year.head()
# Out:
#   country_name  fiscal_year  constant_amount_x
# 0  Afghanistan         2002          677858114
# 1  Afghanistan         2003         1286968141
# 2  Afghanistan         2004         2476465248
# 3  Afghanistan         2005         2141045091
# 4  Afghanistan         2006         3600858850

# %%
# Plot USAID spending for top 10 countries over time
sns.set_context("talk")
plt.figure(figsize=(16, 10))
sns.lineplot(x='fiscal_year', y='constant_amount_x', hue='country_name', data=top_10_by_year);

# %%
# Which income-level countries has the US given the most aid to?
df.groupby('income_group_name').sum().sort_values(
    'constant_amount', ascending = False)['constant_amount']
# Out:
# income_group_name
# Lower Middle Income Country    204302032196
# Upper Middle Income Country    199451410536
# Low Income Country             192088180231
# High Income Country            126189177194
# Name: constant_amount, dtype: int64

# %%
# What type of aid has the US given to High Income Countries?
# df.loc[df.income_group_name == 'High Income Country']['USG_sector_name'].unique()

### Result: all kinds

# %%
# See how much money has been given to various sector programs/purposes
#df.groupby('USG_sector_name').sum().sort_values(
 #   'constant_amount', ascending = False)['constant_amount']

# %%
# Where assistance_category_name = 'Military', what are the kinds of programs?
df.loc[df['assistance_category_name'] == 'Military']['dac_sector_name'].unique()
# Out:
# array(['Conflict, Peace, and Security',
#        'Other Social Infrastructure and Services', 'Other Multisector',
#        'General Environmental Protection', 'Energy', 'Construction',
#        'Trade Policy and Regulations', 'Government and Civil Society',
#        'Health, General', 'Water Supply and Sanitation',
#        'Transport and Storage'], dtype=object)

# %%
# What are the implementing agencies where assistance category = 'Military'?
df.loc[df['assistance_category_name'] == 'Military']['implementing_agency_name'].unique()
# Out:
# array(['Department of Defense', 'Department of the Army',
#        'Department of State', 'Department of the Navy',
#        'Department of the Air Force', 'Department of Homeland Security'],
#       dtype=object)

# %%
# Where assistance_category_name = 'Economic', what are the kinds of programs?
df.loc[df['assistance_category_name'] == 'Economic']['dac_sector_name'].unique()
### Quite a bit of overlap (Economic assistance covers more issues)
# Out:
# array(['Emergency Response', 'Conflict, Peace, and Security',
#        'Basic Health', 'Government and Civil Society',
#        'General Environmental Protection',
#        'Banking and Financial Services', 'Mineral Resources and Mining',
#        'Tourism', 'Water Supply and Sanitation',
#        'Reconstruction Relief and Rehabilitation', 'Communications',
#        'Transport and Storage', 'Operating Expenses', 'Agriculture',
#        'Developmental Food Aid/Food Security Assistance', 'Industry',
#        'Maternal and Child Health, Family Planning', 'Basic Education',
#        'Business and Other Services', 'Construction',
#        'Post-Secondary Education', 'Energy', 'Other Multisector',
#        'Health, General', 'Trade Policy and Regulations',
#        'Other Social Infrastructure and Services',
#        'Education, Level Unspecified', 'HIV/AIDS',
#        'Program Design and Learning',
#        'Disaster Prevention and Preparedness',
#        'Administration and Oversight', 'Secondary Education',
#        'Other Commodity Assistance', 'Unallocated/ Unspecified',
#        'General Budget Support', 'Action Relating To Debt'], dtype=object)

# %%
# What are the implementing agencies where assistance category = 'Economic'?
df.loc[df['assistance_category_name'] == 'Economic']['implementing_agency_name'].unique()
# Out:
# array(['Department of Agriculture', 'Department of Defense',
#        'Department of Health and Human Services', 'Department of State',
#        'Department of the Treasury', 'Trade and Development Agency',
#        'U.S. Agency for International Development', 'Department of Labor',
#        'Department of the Army', 'Department of Transportation',
#        'Department of Homeland Security', 'Department of Justice',
#        'Department of Energy', 'Department of Commerce', 'Peace Corps',
#        'Millennium Challenge Corporation', 'Department of the Interior',
#        'African Development Foundation', 'Inter-American Foundation',
#        'Environmental Protection Agency', 'National Science Foundation',
#        'Open World Leadership Center', 'Federal Trade Commission',
#        'United States Institute of Peace',
#        'Overseas Private Investment Corporation'], dtype=object)

# %%
# How much has the goverment given to aid each year?
total_aid_by_year = df.groupby('fiscal_year').sum().sort_values('fiscal_year', ascending = False)['constant_amount']
total_aid_by_year.plot()

# Looks like aid increased significantly after 9/11 and the Iraq War

# %%
total_aid_by_year
# Out:
# fiscal_year
# 2016    35942127634
# 2015    36716358968
# 2014    31197433715
# 2013    35565150383
# 2012    40405147700
# 2011    41073345423
# 2010    41465339417
# 2009    40261017563
# 2008    42493010981
# 2007    35983314683
# 2006    35376610445
# 2005    32986812486
# 2004    31207849787
# 2003    32182250851
# 2002    18193724835
# 2001    15008100005
# 2000    17955253122
# 1999    16663092082
# 1998    13399074875
# 1997    12518446732
# 1996    13843364304
# 1995    14812793724
# 1994    16550978788
# 1993    16741596121
# 1992    15698755470
# 1991    18801327669
# 1990    18988522394
# Name: constant_amount, dtype: int64

# %%
# Plot economic aid by year (wonder if it's different)

#economic_aid_by_year = 
economic_aid = df.loc[df['assistance_category_name'] == 'Economic']

economic_aid_by_year = economic_aid.groupby('fiscal_year').sum().sort_values(
    'fiscal_year', ascending = False)['constant_amount']

# %%
economic_aid_by_year.plot()

# %%
# Things to do:

# - Map USAID spending for top, like, 20 countries over time
# - Bar graph by year for military vs economic expenditures
# - Line plot for total economic vs military spending over time
# - Line plot comparing US GDP to aid spending?



# For main models, 
# maybe have row for each country, and aggregate sum spent in each 
# 'dac_purpose_name' entry
# or 


###### input should be percent of GDP spent on aid in a given year?

# Figure out if there's a correlation like, every dollar spent results in such and such change

#### what if result was HDI score CHANGE for that year (from year before), inputs are country 
## (countries should be dummy-coded), amount of money spent that year on 'dac_purpose_name'
##  -->> use this to figure out which variables/programs have the biggest effect!!!

# %%
# First, do we want to see if there's correlation between aid received and HDI? 
# like graph money given vs HDI

# %%
df.loc[df['country_name']=='Libya']
# Out:
#       country_name                   region_name            income_group_name  \
# 27749        Libya  Middle East and North Africa  Upper Middle Income Country
# 27750        Libya  Middle East and North Africa  Upper Middle Income Country
# 27751        Libya  Middle East and North Africa  Upper Middle Income Country
# 27752        Libya  Middle East and North Africa  Upper Middle Income Country
# 27753        Libya  Middle East and North Africa  Upper Middle Income Country
# 27754        Libya  Middle East and North Africa  Upper Middle Income Country
# 27755        Libya  Middle East and North Africa  Upper Middle Income Country
# 27756        Libya  Middle East and North Africa  Upper Middle Income Country
# 27757        Libya  Middle East and North Africa  Upper Middle Income Country
# 27758        Libya  Middle East and North Africa  Upper Middle Income Country
# 27759        Libya  Middle East and North Africa  Upper Middle Income Country
# 27760        Libya  Middle East and North Africa  Upper Middle Income Country
# 27761        Libya  Middle East and North Africa  Upper Middle Income Country
# 27762        Libya  Middle East and North Africa  Upper Middle Income Country
# 27763        Libya  Middle East and North Africa  Upper Middle Income Country
# 27764        Libya  Middle East and North Africa  Upper Middle Income Country
# 27765        Libya  Middle East and North Africa  Upper Middle Income Country
# 27766        Libya  Middle East and North Africa  Upper Middle Income Country
# 27767        Libya  Middle East and North Africa  Upper Middle Income Country
# 27768        Libya  Middle East and North Africa  Upper Middle Income Country
# 27769        Libya  Middle East and North Africa  Upper Middle Income Country
# 27770        Libya  Middle East and North Africa  Upper Middle Income Country
# 27771        Libya  Middle East and North Africa  Upper Middle Income Country
# 27772        Libya  Middle East and North Africa  Upper Middle Income Country
# 27773        Libya  Middle East and North Africa  Upper Middle Income Country
# 27774        Libya  Middle East and North Africa  Upper Middle Income Country
# 27775        Libya  Middle East and North Africa  Upper Middle Income Country
# 27776        Libya  Middle East and North Africa  Upper Middle Income Country
# 27777        Libya  Middle East and North Africa  Upper Middle Income Country
# 27778        Libya  Middle East and North Africa  Upper Middle Income Country
# ...            ...                           ...                          ...
# 27828        Libya  Middle East and North Africa  Upper Middle Income Country
# 27829        Libya  Middle East and North Africa  Upper Middle Income Country
# 27830        Libya  Middle East and North Africa  Upper Middle Income Country
# 27831        Libya  Middle East and North Africa  Upper Middle Income Country
# 27832        Libya  Middle East and North Africa  Upper Middle Income Country
# 27833        Libya  Middle East and North Africa  Upper Middle Income Country
# 27834        Libya  Middle East and North Africa  Upper Middle Income Country
# 27835        Libya  Middle East and North Africa  Upper Middle Income Country
# 27836        Libya  Middle East and North Africa  Upper Middle Income Country
# 27837        Libya  Middle East and North Africa  Upper Middle Income Country
# 27838        Libya  Middle East and North Africa  Upper Middle Income Country
# 27839        Libya  Middle East and North Africa  Upper Middle Income Country
# 27840        Libya  Middle East and North Africa  Upper Middle Income Country
# 27841        Libya  Middle East and North Africa  Upper Middle Income Country
# 27842        Libya  Middle East and North Africa  Upper Middle Income Country
# 27843        Libya  Middle East and North Africa  Upper Middle Income Country
# 27844        Libya  Middle East and North Africa  Upper Middle Income Country
# 27845        Libya  Middle East and North Africa  Upper Middle Income Country
# 27846        Libya  Middle East and North Africa  Upper Middle Income Country
# 27847        Libya  Middle East and North Africa  Upper Middle Income Country
# 27848        Libya  Middle East and North Africa  Upper Middle Income Country
# 27849        Libya  Middle East and North Africa  Upper Middle Income Country
# 27850        Libya  Middle East and North Africa  Upper Middle Income Country
# 27851        Libya  Middle East and North Africa  Upper Middle Income Country
# 27852        Libya  Middle East and North Africa  Upper Middle Income Country
# 27853        Libya  Middle East and North Africa  Upper Middle Income Country
# 27854        Libya  Middle East and North Africa  Upper Middle Income Country
# 27855        Libya  Middle East and North Africa  Upper Middle Income Country
# 27856        Libya  Middle East and North Africa  Upper Middle Income Country
# 27857        Libya  Middle East and North Africa  Upper Middle Income Country
#
#        fiscal_year  HDI_Change assistance_category_name  \
# 27749         2004       0.004                 Economic
# 27750         2005       0.004                 Economic
# 27751         2005       0.004                 Economic
# 27752         2006       0.001                 Economic
# 27753         2006       0.001                 Economic
# 27754         2007       0.005                 Economic
# 27755         2007       0.005                 Economic
# 27756         2007       0.005                 Economic
# 27757         2008      -0.002                 Economic
# 27758         2008      -0.002                 Economic
# 27759         2008      -0.002                 Economic
# 27760         2008      -0.002                 Economic
# 27761         2008      -0.002                 Economic
# 27762         2009      -0.000                 Economic
# 27763         2009      -0.000                 Economic
# 27764         2009      -0.000                 Economic
# 27765         2009      -0.000                 Military
# 27766         2010      -0.048                 Economic
# 27767         2010      -0.048                 Economic
# 27768         2010      -0.048                 Economic
# 27769         2010      -0.048                 Economic
# 27770         2010      -0.048                 Military
# 27771         2011       0.034                 Economic
# 27772         2011       0.034                 Economic
# 27773         2011       0.034                 Economic
# 27774         2011       0.034                 Economic
# 27775         2011       0.034                 Economic
# 27776         2011       0.034                 Economic
# 27777         2011       0.034                 Economic
# 27778         2011       0.034                 Military
# ...            ...         ...                      ...
# 27828         2014      -0.001                 Economic
# 27829         2014      -0.001                 Military
# 27830         2015      -0.001                 Economic
# 27831         2015      -0.001                 Economic
# 27832         2015      -0.001                 Economic
# 27833         2015      -0.001                 Economic
# 27834         2015      -0.001                 Economic
# 27835         2015      -0.001                 Economic
# 27836         2015      -0.001                 Economic
# 27837         2015      -0.001                 Economic
# 27838         2015      -0.001                 Economic
# 27839         2015      -0.001                 Economic
# 27840         2015      -0.001                 Economic
# 27841         2015      -0.001                 Economic
# 27842         2016       0.013                 Economic
# 27843         2016       0.013                 Economic
# 27844         2016       0.013                 Economic
# 27845         2016       0.013                 Economic
# 27846         2016       0.013                 Economic
# 27847         2016       0.013                 Economic
# 27848         2016       0.013                 Economic
# 27849         2016       0.013                 Economic
# 27850         2016       0.013                 Economic
# 27851         2016       0.013                 Economic
# 27852         2016       0.013                 Economic
# 27853         2016       0.013                 Economic
# 27854         2016       0.013                 Economic
# 27855         2016       0.013                 Economic
# 27856         2016       0.013                 Economic
# 27857         2016       0.013                 Military
#
#                         implementing_agency_name     dac_category_name  \
# 27749                        Department of State            Governance
# 27750                        Department of State            Governance
# 27751                        Department of State                 Other
# 27752                        Department of State            Governance
# 27753                        Department of State            Governance
# 27754                       Department of Energy        Infrastructure
# 27755                        Department of State            Governance
# 27756                        Department of State            Governance
# 27757                       Department of Energy        Infrastructure
# 27758            Department of Homeland Security       Economic Growth
# 27759                        Department of State            Governance
# 27760                        Department of State            Governance
# 27761                        Department of State                 Other
# 27762                       Department of Energy        Infrastructure
# 27763                        Department of State            Governance
# 27764                        Department of State                 Other
# 27765                      Department of Defense            Governance
# 27766                       Department of Energy        Infrastructure
# 27767                        Department of State            Governance
# 27768                        Department of State            Governance
# 27769                        Department of State            Governance
# 27770                      Department of Defense            Governance
# 27771                      Department of Defense          Humanitarian
# 27772                        Department of State            Governance
# 27773                        Department of State          Humanitarian
# 27774  U.S. Agency for International Development  Administrative Costs
# 27775  U.S. Agency for International Development            Governance
# 27776  U.S. Agency for International Development          Humanitarian
# 27777  U.S. Agency for International Development                 Other
# 27778                      Department of Defense            Governance
# ...                                          ...                   ...
# 27828  U.S. Agency for International Development          Humanitarian
# 27829                      Department of Defense            Governance
# 27830                       Department of Energy        Infrastructure
# 27831                        Department of State            Governance
# 27832                        Department of State            Governance
# 27833                        Department of State          Humanitarian
# 27834  U.S. Agency for International Development  Administrative Costs
# 27835  U.S. Agency for International Development  Administrative Costs
# 27836  U.S. Agency for International Development  Administrative Costs
# 27837  U.S. Agency for International Development       Economic Growth
# 27838  U.S. Agency for International Development            Governance
# 27839  U.S. Agency for International Development            Governance
# 27840  U.S. Agency for International Development          Humanitarian
# 27841  U.S. Agency for International Development                 Other
# 27842                      Department of Defense          Humanitarian
# 27843                       Department of Energy        Infrastructure
# 27844                        Department of State            Governance
# 27845                        Department of State            Governance
# 27846                        Department of State            Governance
# 27847                        Department of State          Humanitarian
# 27848  U.S. Agency for International Development  Administrative Costs
# 27849  U.S. Agency for International Development  Administrative Costs
# 27850  U.S. Agency for International Development  Administrative Costs
# 27851  U.S. Agency for International Development       Economic Growth
# 27852  U.S. Agency for International Development            Governance
# 27853  U.S. Agency for International Development            Governance
# 27854  U.S. Agency for International Development            Governance
# 27855  U.S. Agency for International Development          Humanitarian
# 27856  U.S. Agency for International Development                 Other
# 27857                      Department of Defense            Governance
#
#                                 dac_sector_name  constant_amount
# 27749              Government and Civil Society            51061
# 27750              Government and Civil Society           101487
# 27751          General Environmental Protection            56561
# 27752             Conflict, Peace, and Security         29966589
# 27753              Government and Civil Society           133052
# 27754                                    Energy          3691124
# 27755             Conflict, Peace, and Security          1166976
# 27756              Government and Civil Society           196052
# 27757                                    Energy          5677320
# 27758              Trade Policy and Regulations            43527
# 27759             Conflict, Peace, and Security           292364
# 27760              Government and Civil Society           400137
# 27761                         Other Multisector          4572989
# 27762                                    Energy          8465545
# 27763              Government and Civil Society           222291
# 27764                         Other Multisector          3367698
# 27765  Other Social Infrastructure and Services            11301
# 27766                                    Energy         25370599
# 27767             Conflict, Peace, and Security           845783
# 27768              Government and Civil Society           393248
# 27769  Other Social Infrastructure and Services            83458
# 27770             Conflict, Peace, and Security           525393
# 27771                        Emergency Response          1317517
# 27772              Government and Civil Society           520419
# 27773                        Emergency Response         65107286
# 27774              Administration and Oversight           134594
# 27775             Conflict, Peace, and Security          3873264
# 27776                        Emergency Response         25494804
# 27777                         Other Multisector            21444
# 27778             Conflict, Peace, and Security         32937919
# ...                                         ...              ...
# 27828                        Emergency Response           -96782
# 27829             Conflict, Peace, and Security          1561016
# 27830                                    Energy           237688
# 27831             Conflict, Peace, and Security           139182
# 27832              Government and Civil Society           574197
# 27833                        Emergency Response          5967932
# 27834              Administration and Oversight           977900
# 27835                        Operating Expenses           926687
# 27836               Program Design and Learning            36534
# 27837              Trade Policy and Regulations          -246311
# 27838             Conflict, Peace, and Security          2538376
# 27839              Government and Civil Society          4784032
# 27840                        Emergency Response            -5761
# 27841                         Other Multisector            81618
# 27842                        Emergency Response            -5086
# 27843                                    Energy           330587
# 27844             Conflict, Peace, and Security          1548166
# 27845              Government and Civil Society          1467809
# 27846  Other Social Infrastructure and Services           104068
# 27847                        Emergency Response          8035816
# 27848              Administration and Oversight           719444
# 27849                        Operating Expenses           389204
# 27850               Program Design and Learning            59424
# 27851            Banking and Financial Services         -2034383
# 27852             Conflict, Peace, and Security         14092988
# 27853              Government and Civil Society          1881805
# 27854  Other Social Infrastructure and Services          -207845
# 27855                        Emergency Response          2184104
# 27856                         Other Multisector            21051
# 27857             Conflict, Peace, and Security             8235
#
# [109 rows x 10 columns]
